# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# # Train Validation Set Split

# %%
def train_valid_split(data, ratio=0.1, batchSize=4, shuffle = True):
    nSample = len(data)
    
    if shuffle:
        index = torch.randperm(nSample)
    else:
        index = torch.arange(0,nSample)
    
    nValid = int(nSample*ratio)
    
    validIndex, trainIndex = index[:nValid], index[nValid:]
    
    validSampler = torch.utils.data.sampler.SubsetRandomSampler(validIndex)
    
    trainSampler = torch.utils.data.sampler.SubsetRandomSampler(trainIndex)
    
    trainloader = torch.utils.data.DataLoader(data, batch_size=batchSize,
                                         sampler=trainSampler, num_workers=2)
    
    validloader = torch.utils.data.DataLoader(data, batch_size=batchSize,
                                         sampler=validSampler, num_workers=2)
    
    return trainloader, validloader, trainSampler

# %%
batchSize = 128
transformTrain = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
     transforms.RandomCrop(28),
     transforms.Scale(32),
     transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])
     #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
    
transformTest = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])

trainset = torchvision.datasets.CIFAR10(root='./datasets/CIFAR-10', train=True,
                                        download=True, transform=transformTrain)

testset = torchvision.datasets.CIFAR10(root='./datasets/CIFAR-10', train=False,
                                       download=True, transform=transformTest)

testloader = torch.utils.data.DataLoader(testset, batch_size=batchSize,
                                         num_workers=2)

trainloader, validloader, trainSampler = train_valid_split(trainset, batchSize = batchSize)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# 3. Accuracy 90.24%
#
# $INPUT -> [[CONV -> RRELU -> BN] * 4 -> POOL] * 2 -> [FC -> RRELU] * 2 -> FC$

# %%
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding = 1)
        self.conv12_bn = nn.BatchNorm2d(64)
        
        self.conv2 = nn.Conv2d(64, 64, 3, padding = 1)
        
        self.conv3 = nn.Conv2d(64, 128, 3, padding = 1)
        self.conv34_bn = nn.BatchNorm2d(128)
        
        self.conv4 = nn.Conv2d(128, 128, 3, padding = 1)
        self.pool1 = nn.MaxPool2d(2, 2)
        
        self.conv5 = nn.Conv2d(128, 256, 3, padding = 1)
        self.conv56_bn = nn.BatchNorm2d(256)
        
        self.conv6 = nn.Conv2d(256, 256, 3, padding = 1)
        
        self.conv7 = nn.Conv2d(256, 512, 3, padding = 1)
        self.conv78_bn = nn.BatchNorm2d(512)
        
        self.conv8 = nn.Conv2d(512, 512, 3, padding = 1)
        self.pool2 = nn.MaxPool2d(2, 2)
        
        self.fc1 = nn.Linear(512 * 8 * 8, 4096)
        nn.init.xavier_normal(self.fc1.weight)
        
        self.fc2 = nn.Linear(4096, 4096)
        nn.init.xavier_normal(self.fc2.weight)
        
        self.fc3 = nn.Linear(4096, 10)
        nn.init.xavier_normal(self.fc3.weight)

    def forward(self, x):
        x = self.conv12_bn(F.rrelu(self.conv1(x)))
        x = self.conv12_bn(F.rrelu(self.conv2(x)))
        x = self.conv34_bn(F.rrelu(self.conv3(x)))
        x = self.conv34_bn(self.pool1(F.rrelu(self.conv4(x))))
        
        x = self.conv56_bn(F.rrelu(self.conv5(x)))
        x = self.conv56_bn(F.rrelu(self.conv6(x)))
        x = self.conv78_bn(F.rrelu(self.conv7(x)))
        x = self.conv78_bn(self.pool2(F.rrelu(self.conv8(x))))
        
        x = x.view(-1, 512 * 8 * 8)
        x = F.rrelu(self.fc1(x))
        x = F.rrelu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net().cuda()
print(net)
# Out:
# Net (
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv12_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv34_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv56_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (conv6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv7): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv78_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#   (conv8): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (fc1): Linear (32768 -> 4096)
#   (fc2): Linear (4096 -> 4096)
#   (fc3): Linear (4096 -> 10)
# )

# %%
def Accuracy(dataloader):
    correct = 0
    total = 0
    for data in dataloader:
        images, labels = data
        outputs = net(Variable(images).cuda())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.cuda()).sum()
    return 100.0 * correct / total

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
#optimizer = optim.Adam(net.parameters(), lr=0.001)#, weight_decay = 0.001)
optimizer = optim.SGD(net.parameters(), lr=0.005, momentum=0.9, weight_decay = 0.001)

maxIter = 100
trainAcc = torch.zeros(maxIter)
validAcc = torch.zeros(maxIter)
testAcc = torch.zeros(maxIter)

#earlyStopping = torch.zeros(3)
#bestPara = net.parameters()

for epoch in range(100):# loop over the dataset multiple times
    #trainloader = torch.utils.data.DataLoader(trainset, batch_size=batchSize,
    #                                sampler=trainSampler, num_workers=2)
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.data[0]
    print('[%d, %5d] loss: %.3f' %
            (epoch + 1, i + 1, running_loss / len(trainloader)))
    running_loss = 0.0
    trainAcc[epoch] = Accuracy(trainloader)
    print('Accuracy of the network on the 45000 train images: %5.2f %%' % (trainAcc[epoch]))

    validAcc[epoch] = Accuracy(validloader)
    print('Accuracy of the network on the 5000 valid images: %5.2f %%' % (validAcc[epoch]))

    testAcc[epoch] = Accuracy(testloader)
    print('Accuracy of the network on the 10000 test images: %5.2f %%' % (testAcc[epoch]))
    
    #earlyStopping[2] = earlyStopping[1]
    #earlyStopping[1] = earlyStopping[0]
    #earlyStopping[0] = validAcc[epoch]
    
    
    #if validAcc > earlyStopping[1]:
    #    bestPara = net.parameters()
    
    #if epoch > 15 and earlyStopping[0] < earlyStopping[1] < earlyStopping[2]:
    #    print('Statisfy the earlyStopping condition')
    #    break;
#net.parameters() = bestPara
print('Finished Training')
# Out:
# [1,   352] loss: 1.255
# Accuracy of the network on the 45000 train images: 67.58 %
# Accuracy of the network on the 5000 valid images: 66.44 %
# Accuracy of the network on the 10000 test images: 68.30 %
# [2,   352] loss: 0.812
# Accuracy of the network on the 45000 train images: 74.90 %
# Accuracy of the network on the 5000 valid images: 74.28 %
# Accuracy of the network on the 10000 test images: 74.00 %
# [3,   352] loss: 0.666
# Accuracy of the network on the 45000 train images: 78.40 %
# Accuracy of the network on the 5000 valid images: 75.44 %
# Accuracy of the network on the 10000 test images: 76.71 %
# [4,   352] loss: 0.587
# Accuracy of the network on the 45000 train images: 81.04 %
# Accuracy of the network on the 5000 valid images: 77.96 %
# Accuracy of the network on the 10000 test images: 78.73 %
# [5,   352] loss: 0.530
# Accuracy of the network on the 45000 train images: 84.11 %
# Accuracy of the network on the 5000 valid images: 80.52 %
# Accuracy of the network on the 10000 test images: 81.58 %
# [6,   352] loss: 0.473
# Accuracy of the network on the 45000 train images: 85.53 %
# Accuracy of the network on the 5000 valid images: 81.04 %
# Accuracy of the network on the 10000 test images: 81.55 %
# [7,   352] loss: 0.433
# Accuracy of the network on the 45000 train images: 86.48 %
# Accuracy of the network on the 5000 valid images: 82.38 %
# Accuracy of the network on the 10000 test images: 81.99 %
# [8,   352] loss: 0.400
# Accuracy of the network on the 45000 train images: 87.50 %
# Accuracy of the network on the 5000 valid images: 82.50 %
# Accuracy of the network on the 10000 test images: 83.26 %
# [9,   352] loss: 0.374
# Accuracy of the network on the 45000 train images: 88.55 %
# Accuracy of the network on the 5000 valid images: 83.00 %
# Accuracy of the network on the 10000 test images: 84.16 %
# [10,   352] loss: 0.346
# Accuracy of the network on the 45000 train images: 89.22 %
# Accuracy of the network on the 5000 valid images: 84.22 %
# Accuracy of the network on the 10000 test images: 84.55 %
# [11,   352] loss: 0.322
# Accuracy of the network on the 45000 train images: 89.98 %
# Accuracy of the network on the 5000 valid images: 83.94 %
# Accuracy of the network on the 10000 test images: 84.14 %
# [12,   352] loss: 0.301
# Accuracy of the network on the 45000 train images: 90.28 %
# Accuracy of the network on the 5000 valid images: 84.70 %
# Accuracy of the network on the 10000 test images: 84.85 %
# [13,   352] loss: 0.281
# Accuracy of the network on the 45000 train images: 90.98 %
# Accuracy of the network on the 5000 valid images: 85.20 %
# Accuracy of the network on the 10000 test images: 85.17 %
# [14,   352] loss: 0.270
# Accuracy of the network on the 45000 train images: 91.56 %
# Accuracy of the network on the 5000 valid images: 85.36 %
# Accuracy of the network on the 10000 test images: 85.69 %
# [15,   352] loss: 0.246
# Accuracy of the network on the 45000 train images: 92.40 %
# Accuracy of the network on the 5000 valid images: 86.10 %
# Accuracy of the network on the 10000 test images: 86.08 %
# [16,   352] loss: 0.235
# Accuracy of the network on the 45000 train images: 92.64 %
# Accuracy of the network on the 5000 valid images: 85.30 %
# Accuracy of the network on the 10000 test images: 85.79 %
# [17,   352] loss: 0.226
# Accuracy of the network on the 45000 train images: 92.83 %
# Accuracy of the network on the 5000 valid images: 86.28 %
# Accuracy of the network on the 10000 test images: 85.61 %
# [18,   352] loss: 0.213
# Accuracy of the network on the 45000 train images: 93.62 %
# Accuracy of the network on the 5000 valid images: 86.24 %
# Accuracy of the network on the 10000 test images: 86.69 %
# [19,   352] loss: 0.201
# Accuracy of the network on the 45000 train images: 94.04 %
# Accuracy of the network on the 5000 valid images: 87.22 %
# Accuracy of the network on the 10000 test images: 86.49 %
# [20,   352] loss: 0.193
# Accuracy of the network on the 45000 train images: 94.20 %
# Accuracy of the network on the 5000 valid images: 86.76 %
# Accuracy of the network on the 10000 test images: 86.70 %
# [21,   352] loss: 0.182
# Accuracy of the network on the 45000 train images: 94.74 %
# Accuracy of the network on the 5000 valid images: 87.38 %
# Accuracy of the network on the 10000 test images: 87.40 %
# [22,   352] loss: 0.176
# Accuracy of the network on the 45000 train images: 94.68 %
# Accuracy of the network on the 5000 valid images: 87.00 %
# Accuracy of the network on the 10000 test images: 87.34 %
# [23,   352] loss: 0.164
# Accuracy of the network on the 45000 train images: 95.08 %
# Accuracy of the network on the 5000 valid images: 86.70 %
# Accuracy of the network on the 10000 test images: 87.48 %
# [24,   352] loss: 0.153
# Accuracy of the network on the 45000 train images: 95.18 %
# Accuracy of the network on the 5000 valid images: 87.28 %
# Accuracy of the network on the 10000 test images: 87.73 %
# [25,   352] loss: 0.152
# Accuracy of the network on the 45000 train images: 95.79 %
# Accuracy of the network on the 5000 valid images: 87.24 %
# Accuracy of the network on the 10000 test images: 87.28 %
# [26,   352] loss: 0.147
# Accuracy of the network on the 45000 train images: 95.66 %
# Accuracy of the network on the 5000 valid images: 87.72 %
# Accuracy of the network on the 10000 test images: 87.27 %
# [27,   352] loss: 0.141
# Accuracy of the network on the 45000 train images: 96.01 %
# Accuracy of the network on the 5000 valid images: 87.76 %
# Accuracy of the network on the 10000 test images: 87.91 %
# [28,   352] loss: 0.137
# Accuracy of the network on the 45000 train images: 95.84 %
# Accuracy of the network on the 5000 valid images: 87.36 %
# Accuracy of the network on the 10000 test images: 86.94 %
# [29,   352] loss: 0.129
# Accuracy of the network on the 45000 train images: 96.40 %
# Accuracy of the network on the 5000 valid images: 87.82 %
# Accuracy of the network on the 10000 test images: 87.95 %
# [30,   352] loss: 0.123
# Accuracy of the network on the 45000 train images: 96.62 %
# Accuracy of the network on the 5000 valid images: 87.68 %
# Accuracy of the network on the 10000 test images: 87.63 %
# [31,   352] loss: 0.117
# Accuracy of the network on the 45000 train images: 96.14 %
# Accuracy of the network on the 5000 valid images: 87.54 %
# Accuracy of the network on the 10000 test images: 87.57 %
# [32,   352] loss: 0.116
# Accuracy of the network on the 45000 train images: 96.91 %
# Accuracy of the network on the 5000 valid images: 88.34 %
# Accuracy of the network on the 10000 test images: 88.42 %
# [33,   352] loss: 0.119
# Accuracy of the network on the 45000 train images: 96.97 %
# Accuracy of the network on the 5000 valid images: 88.12 %
# Accuracy of the network on the 10000 test images: 88.19 %
# [34,   352] loss: 0.105
# Accuracy of the network on the 45000 train images: 97.07 %
# Accuracy of the network on the 5000 valid images: 88.38 %
# Accuracy of the network on the 10000 test images: 88.22 %
# [35,   352] loss: 0.104
# Accuracy of the network on the 45000 train images: 96.80 %
# Accuracy of the network on the 5000 valid images: 87.96 %
# Accuracy of the network on the 10000 test images: 88.49 %
# [36,   352] loss: 0.104
# Accuracy of the network on the 45000 train images: 97.17 %
# Accuracy of the network on the 5000 valid images: 88.56 %
# Accuracy of the network on the 10000 test images: 88.28 %
# [37,   352] loss: 0.105
# Accuracy of the network on the 45000 train images: 96.92 %
# Accuracy of the network on the 5000 valid images: 88.20 %
# Accuracy of the network on the 10000 test images: 88.31 %
# [38,   352] loss: 0.098
# Accuracy of the network on the 45000 train images: 97.02 %
# Accuracy of the network on the 5000 valid images: 88.40 %
# Accuracy of the network on the 10000 test images: 88.15 %
# [39,   352] loss: 0.096
# Accuracy of the network on the 45000 train images: 97.39 %
# Accuracy of the network on the 5000 valid images: 88.26 %
# Accuracy of the network on the 10000 test images: 88.29 %
# [40,   352] loss: 0.091
# Accuracy of the network on the 45000 train images: 97.26 %
# Accuracy of the network on the 5000 valid images: 88.72 %
# Accuracy of the network on the 10000 test images: 88.32 %
# [41,   352] loss: 0.090
# Accuracy of the network on the 45000 train images: 96.91 %
# Accuracy of the network on the 5000 valid images: 87.82 %
# Accuracy of the network on the 10000 test images: 88.01 %
# [42,   352] loss: 0.091
# Accuracy of the network on the 45000 train images: 97.47 %
# Accuracy of the network on the 5000 valid images: 88.82 %
# Accuracy of the network on the 10000 test images: 88.26 %
# [43,   352] loss: 0.087
# Accuracy of the network on the 45000 train images: 97.39 %
# Accuracy of the network on the 5000 valid images: 88.90 %
# Accuracy of the network on the 10000 test images: 88.79 %
# [44,   352] loss: 0.082
# Accuracy of the network on the 45000 train images: 97.59 %
# Accuracy of the network on the 5000 valid images: 88.58 %
# Accuracy of the network on the 10000 test images: 88.66 %
# [45,   352] loss: 0.080
# Accuracy of the network on the 45000 train images: 97.48 %
# Accuracy of the network on the 5000 valid images: 88.56 %
# Accuracy of the network on the 10000 test images: 88.47 %
# [46,   352] loss: 0.082
# Accuracy of the network on the 45000 train images: 97.55 %
# Accuracy of the network on the 5000 valid images: 88.56 %
# Accuracy of the network on the 10000 test images: 88.54 %
# [47,   352] loss: 0.078
# Accuracy of the network on the 45000 train images: 97.85 %
# Accuracy of the network on the 5000 valid images: 89.44 %
# Accuracy of the network on the 10000 test images: 88.83 %
# [48,   352] loss: 0.077
# Accuracy of the network on the 45000 train images: 97.76 %
# Accuracy of the network on the 5000 valid images: 88.26 %
# Accuracy of the network on the 10000 test images: 88.61 %
# [49,   352] loss: 0.078
# Accuracy of the network on the 45000 train images: 97.74 %
# Accuracy of the network on the 5000 valid images: 88.76 %
# Accuracy of the network on the 10000 test images: 88.76 %
# [50,   352] loss: 0.075
# Accuracy of the network on the 45000 train images: 97.66 %
# Accuracy of the network on the 5000 valid images: 88.28 %
# Accuracy of the network on the 10000 test images: 88.30 %
# [51,   352] loss: 0.075
# Accuracy of the network on the 45000 train images: 97.92 %
# Accuracy of the network on the 5000 valid images: 89.04 %
# Accuracy of the network on the 10000 test images: 88.48 %
# [52,   352] loss: 0.076
# Accuracy of the network on the 45000 train images: 97.52 %
# Accuracy of the network on the 5000 valid images: 88.54 %
# Accuracy of the network on the 10000 test images: 88.18 %
# [53,   352] loss: 0.073
# Accuracy of the network on the 45000 train images: 98.22 %
# Accuracy of the network on the 5000 valid images: 88.46 %
# Accuracy of the network on the 10000 test images: 88.91 %
# [54,   352] loss: 0.072
# Accuracy of the network on the 45000 train images: 97.98 %
# Accuracy of the network on the 5000 valid images: 88.96 %
# Accuracy of the network on the 10000 test images: 89.05 %
# [55,   352] loss: 0.067
# Accuracy of the network on the 45000 train images: 97.93 %
# Accuracy of the network on the 5000 valid images: 89.02 %
# Accuracy of the network on the 10000 test images: 88.67 %
# [56,   352] loss: 0.069
# Accuracy of the network on the 45000 train images: 98.28 %
# Accuracy of the network on the 5000 valid images: 88.84 %
# Accuracy of the network on the 10000 test images: 88.90 %
# [57,   352] loss: 0.071
# Accuracy of the network on the 45000 train images: 97.95 %
# Accuracy of the network on the 5000 valid images: 89.50 %
# Accuracy of the network on the 10000 test images: 89.15 %
# [58,   352] loss: 0.073
# Accuracy of the network on the 45000 train images: 98.24 %
# Accuracy of the network on the 5000 valid images: 89.32 %
# Accuracy of the network on the 10000 test images: 88.59 %
# [59,   352] loss: 0.069
# Accuracy of the network on the 45000 train images: 98.02 %
# Accuracy of the network on the 5000 valid images: 89.10 %
# Accuracy of the network on the 10000 test images: 88.79 %
# [60,   352] loss: 0.068
# Accuracy of the network on the 45000 train images: 97.82 %
# Accuracy of the network on the 5000 valid images: 88.08 %
# Accuracy of the network on the 10000 test images: 88.17 %
# [61,   352] loss: 0.069
# Accuracy of the network on the 45000 train images: 98.23 %
# Accuracy of the network on the 5000 valid images: 89.54 %
# Accuracy of the network on the 10000 test images: 89.37 %
# [62,   352] loss: 0.071
# Accuracy of the network on the 45000 train images: 98.14 %
# Accuracy of the network on the 5000 valid images: 88.74 %
# Accuracy of the network on the 10000 test images: 89.40 %
# [63,   352] loss: 0.066
# Accuracy of the network on the 45000 train images: 98.14 %
# Accuracy of the network on the 5000 valid images: 88.72 %
# Accuracy of the network on the 10000 test images: 89.32 %
# [64,   352] loss: 0.067
# Accuracy of the network on the 45000 train images: 98.25 %
# Accuracy of the network on the 5000 valid images: 89.50 %
# Accuracy of the network on the 10000 test images: 89.35 %
# [65,   352] loss: 0.064
# Accuracy of the network on the 45000 train images: 98.25 %
# Accuracy of the network on the 5000 valid images: 89.54 %
# Accuracy of the network on the 10000 test images: 89.65 %
# [66,   352] loss: 0.065
# Accuracy of the network on the 45000 train images: 98.04 %
# Accuracy of the network on the 5000 valid images: 88.92 %
# Accuracy of the network on the 10000 test images: 89.03 %
# [67,   352] loss: 0.065
# Accuracy of the network on the 45000 train images: 98.38 %
# Accuracy of the network on the 5000 valid images: 89.54 %
# Accuracy of the network on the 10000 test images: 89.50 %
# [68,   352] loss: 0.061
# Accuracy of the network on the 45000 train images: 97.88 %
# Accuracy of the network on the 5000 valid images: 88.96 %
# Accuracy of the network on the 10000 test images: 88.77 %
# [69,   352] loss: 0.065
# Accuracy of the network on the 45000 train images: 97.85 %
# Accuracy of the network on the 5000 valid images: 88.44 %
# Accuracy of the network on the 10000 test images: 88.77 %
# [70,   352] loss: 0.065
# Accuracy of the network on the 45000 train images: 98.46 %
# Accuracy of the network on the 5000 valid images: 89.78 %
# Accuracy of the network on the 10000 test images: 89.69 %
# [71,   352] loss: 0.058
# Accuracy of the network on the 45000 train images: 98.07 %
# Accuracy of the network on the 5000 valid images: 88.44 %
# Accuracy of the network on the 10000 test images: 88.92 %
# [72,   352] loss: 0.062
# Accuracy of the network on the 45000 train images: 98.01 %
# Accuracy of the network on the 5000 valid images: 89.04 %
# Accuracy of the network on the 10000 test images: 89.21 %
# [73,   352] loss: 0.057
# Accuracy of the network on the 45000 train images: 98.47 %
# Accuracy of the network on the 5000 valid images: 90.14 %
# Accuracy of the network on the 10000 test images: 89.69 %
# [74,   352] loss: 0.056
# Accuracy of the network on the 45000 train images: 98.23 %
# Accuracy of the network on the 5000 valid images: 89.50 %
# Accuracy of the network on the 10000 test images: 89.52 %
# [75,   352] loss: 0.059
# Accuracy of the network on the 45000 train images: 98.54 %
# Accuracy of the network on the 5000 valid images: 89.68 %
# Accuracy of the network on the 10000 test images: 89.58 %
# [76,   352] loss: 0.059
# Accuracy of the network on the 45000 train images: 98.32 %
# Accuracy of the network on the 5000 valid images: 89.36 %
# Accuracy of the network on the 10000 test images: 89.22 %
# [77,   352] loss: 0.060
# Accuracy of the network on the 45000 train images: 98.29 %
# Accuracy of the network on the 5000 valid images: 89.56 %
# Accuracy of the network on the 10000 test images: 89.12 %
# [78,   352] loss: 0.063
# Accuracy of the network on the 45000 train images: 98.36 %
# Accuracy of the network on the 5000 valid images: 90.02 %
# Accuracy of the network on the 10000 test images: 89.50 %
# [79,   352] loss: 0.063
# Accuracy of the network on the 45000 train images: 98.23 %
# Accuracy of the network on the 5000 valid images: 88.92 %
# Accuracy of the network on the 10000 test images: 89.33 %
# [80,   352] loss: 0.057
# Accuracy of the network on the 45000 train images: 98.48 %
# Accuracy of the network on the 5000 valid images: 89.18 %
# Accuracy of the network on the 10000 test images: 89.75 %
# [81,   352] loss: 0.060
# Accuracy of the network on the 45000 train images: 98.42 %
# Accuracy of the network on the 5000 valid images: 89.18 %
# Accuracy of the network on the 10000 test images: 89.71 %
# [82,   352] loss: 0.061
# Accuracy of the network on the 45000 train images: 98.13 %
# Accuracy of the network on the 5000 valid images: 88.98 %
# Accuracy of the network on the 10000 test images: 89.16 %
# [83,   352] loss: 0.062
# Accuracy of the network on the 45000 train images: 98.42 %
# Accuracy of the network on the 5000 valid images: 89.58 %
# Accuracy of the network on the 10000 test images: 89.83 %
# [84,   352] loss: 0.057
# Accuracy of the network on the 45000 train images: 98.43 %
# Accuracy of the network on the 5000 valid images: 88.88 %
# Accuracy of the network on the 10000 test images: 89.66 %
# [85,   352] loss: 0.058
# Accuracy of the network on the 45000 train images: 98.74 %
# Accuracy of the network on the 5000 valid images: 90.02 %
# Accuracy of the network on the 10000 test images: 89.65 %
# [86,   352] loss: 0.054
# Accuracy of the network on the 45000 train images: 98.40 %
# Accuracy of the network on the 5000 valid images: 89.96 %
# Accuracy of the network on the 10000 test images: 89.36 %
# [87,   352] loss: 0.059
# Accuracy of the network on the 45000 train images: 98.16 %
# Accuracy of the network on the 5000 valid images: 89.30 %
# Accuracy of the network on the 10000 test images: 89.79 %
# [88,   352] loss: 0.057
# Accuracy of the network on the 45000 train images: 98.35 %
# Accuracy of the network on the 5000 valid images: 89.76 %
# Accuracy of the network on the 10000 test images: 89.34 %
# [89,   352] loss: 0.055
# Accuracy of the network on the 45000 train images: 98.52 %
# Accuracy of the network on the 5000 valid images: 89.72 %
# Accuracy of the network on the 10000 test images: 89.83 %
# [90,   352] loss: 0.056
# Accuracy of the network on the 45000 train images: 98.50 %
# Accuracy of the network on the 5000 valid images: 89.64 %
# Accuracy of the network on the 10000 test images: 89.39 %
# [91,   352] loss: 0.054
# Accuracy of the network on the 45000 train images: 98.44 %
# Accuracy of the network on the 5000 valid images: 89.48 %
# Accuracy of the network on the 10000 test images: 89.65 %
# [92,   352] loss: 0.057
# Accuracy of the network on the 45000 train images: 98.39 %
# Accuracy of the network on the 5000 valid images: 89.40 %
# Accuracy of the network on the 10000 test images: 89.94 %
# [93,   352] loss: 0.060
# Accuracy of the network on the 45000 train images: 98.18 %
# Accuracy of the network on the 5000 valid images: 89.20 %
# Accuracy of the network on the 10000 test images: 89.34 %
# [94,   352] loss: 0.052
# Accuracy of the network on the 45000 train images: 98.47 %
# Accuracy of the network on the 5000 valid images: 89.56 %
# Accuracy of the network on the 10000 test images: 89.31 %
# [95,   352] loss: 0.052
# Accuracy of the network on the 45000 train images: 98.56 %
# Accuracy of the network on the 5000 valid images: 89.70 %
# Accuracy of the network on the 10000 test images: 89.83 %
# [96,   352] loss: 0.053
# Accuracy of the network on the 45000 train images: 98.59 %
# Accuracy of the network on the 5000 valid images: 89.64 %
# Accuracy of the network on the 10000 test images: 89.87 %
# [97,   352] loss: 0.052
# Accuracy of the network on the 45000 train images: 98.84 %
# Accuracy of the network on the 5000 valid images: 89.94 %
# Accuracy of the network on the 10000 test images: 89.93 %
# [98,   352] loss: 0.057
# Accuracy of the network on the 45000 train images: 98.35 %
# Accuracy of the network on the 5000 valid images: 89.44 %
# Accuracy of the network on the 10000 test images: 89.60 %
# [99,   352] loss: 0.059
# Accuracy of the network on the 45000 train images: 98.20 %
# Accuracy of the network on the 5000 valid images: 88.98 %
# Accuracy of the network on the 10000 test images: 89.17 %
# [100,   352] loss: 0.057
# Accuracy of the network on the 45000 train images: 98.56 %
# Accuracy of the network on the 5000 valid images: 90.14 %
# Accuracy of the network on the 10000 test images: 90.24 %
# Finished Training

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
for data in testloader:
    images, labels = data
    outputs = net(Variable(images).cuda())
    _, predicted = torch.max(outputs.data, 1)
    c = (predicted == labels.cuda()).squeeze()
    for i in range(len(labels)):
        label = labels[i]
        class_correct[label] += c[i]
        class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %5.2f %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 90.00 %
# Accuracy of   car : 95.60 %
# Accuracy of  bird : 87.20 %
# Accuracy of   cat : 78.60 %
# Accuracy of  deer : 90.90 %
# Accuracy of   dog : 83.60 %
# Accuracy of  frog : 95.20 %
# Accuracy of horse : 93.00 %
# Accuracy of  ship : 94.70 %
# Accuracy of truck : 93.60 %

# %%
print('Accuracy of the network on the 10000 test images: %5.2f %%' % (testAcc.max()))
x = [i for i in range(epoch+1)]
plt.figure(figsize = (8,6))
trainRate, = plt.plot(x, trainAcc.numpy())
validRate, = plt.plot(x, validAcc.numpy())
testRate, = plt.plot(x, testAcc.numpy())
plt.legend([trainRate, validRate, testRate], ['trainRate', 'validRate', 'testRate'])
plt.xlabel('# of iteration')
plt.ylabel('Percent Correct Classification')
plt.title('Percent Correct Classification of CNN-1')
plt.grid()
plt.show()
# Out:
# Accuracy of the network on the 10000 test images: 90.24 %
